# %% [markdown]
# # GIA-OLYMPICS

# %% [markdown]
# ## SWIMMING COMPETITION

# %% [markdown]
# ### Exportamos el metodo encargado de la simulación

# %%
from tournaments_setup_deploy import tournament_setup_deploy as tsd
from IPython.display import display
import pandas as pd 
import time

# %% [markdown]
# ### Ajustamos la cantidad de simulaciones

# %%
amount_of_simulations = 1000

places=["first","second",'third']

pd.set_option("display.max_rows",None)
pd.set_option("display.max_columns",None)

# %% [markdown]
# ### Recibimos los 3 dataframes del podio de cada simulación

# %%
clock = time.time()
dfs = tsd(amount_of_simulations)
clock = time.time()-clock
print(f"Done in {round(clock,3)} secs")
# Out:
# Done in 385.056 secs

# %% [markdown]
# ### Ahora ploteamos esos datos

# %%
for i,df in enumerate(dfs):
    print(f"{places[i].capitalize()} Place")
    display(df)
    print("\n\n\n")
# Out:
# First Place
#                       Event                         Name  Percent
# 0       M-800-FREESTYLE-LCM             WOJDAK, Wojciech     15.8
# 1       M-800-FREESTYLE-LCM              DETTI, Gabriele     12.7
# 2       M-800-FREESTYLE-LCM               COCHRANE, Ryan     11.5
# 3       M-800-FREESTYLE-LCM        COLBERTALDO, Federico     11.2
# 4       M-800-FREESTYLE-LCM                 AUBRY, David     10.5
# 5       M-800-FREESTYLE-LCM          ROMANCHUK, Mykhailo      7.6
# 6       M-800-FREESTYLE-LCM        MCLOUGHLIN, Jack Alan      7.4
# 7       M-800-FREESTYLE-LCM         CHRISTIANSEN, Henrik      6.3
# 8       M-800-FREESTYLE-LCM                   KIS, Gergo      6.1
# 9       M-800-FREESTYLE-LCM            MC BROOM, Michael      4.5
# 10      M-800-FREESTYLE-LCM               JAEGER, Connor      1.8
# 11      M-800-FREESTYLE-LCM           WELLBROCK, Florian      1.2
# 12      M-800-FREESTYLE-LCM                 GROTHE, Zane      0.9
# ...
